# %% [markdown]
# <a href="https://colab.research.google.com/github/vermilion4/pythonChart/blob/master/Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data = pd.read_csv(url,error_bad_lines=False)

plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
#sns.barplot(data=fuel_unit, x='unit', y='count')
#plt.xlabel('Fuel Unit')

#f = sns.barplot(data=fuel_unit,x='unit',y='count')
#f.set_yscale('log')
#f.set_ylim(1,12000)
#plt.xlabel('Fuel Unit')

sample_df = fuel_data.sample(n=50,random_state=4)
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
from google.colab.patches import cv2_imshow

# %%
# !curl -o logo.png https://colab.research.google.com/img/colab_favicon_256px.png
import cv2
img = cv2.imread('logo.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
          palette=["b", "r"], data=fuel_data)

#sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color="b")

# %%
sns.violinplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
            palette=["m", "g"], data=fuel_data)
